# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

plt.style.use('seaborn')

# %%
def labeling(labels, values):
    for i in range(len(labels)):
        plt.text(i, values[i], values[i], ha = 'center', bbox = dict(facecolor = 'lightblue', alpha =.8))

# %%
df = pd.read_csv('./database.csv')
df
# Out:
#     mode result
# 0      1      O
# 1      2      X
# 2      1      X
# 3      1      X
# 4      1      D
# 5      2      X
# 6      1      O
# 7      2      X
# 8      2      X
# 9      2      O
# 10     2      O
# 11     1      X
# 12     2      D
# 13     2      X
# 14     1      X
# 15     2      O
# 16     1      D
# 17     1      X
# 18     1      O
# 19     1      O
# 20     1      X
# 21     1      X
# 22     1      X
# 23     1      X
# 24     1      X
# 25     1      X
# 26     1      O
# 27     1      O
# 28     1      X
# 29     1      X
# 30     1      X
# 31     2      D

# %%
# Statistics ONE: How many games were played against the computer? And how many between human players?
modes = df['mode'].value_counts().keys().tolist()
game_counts = df['mode'].value_counts().tolist()

modes[0] = str(modes[0]) + ' Player'
modes[1] = str(modes[1]) + ' Players'

plt.figure(figsize=(6, 8), dpi=120)
plt.bar(modes, game_counts, width=0.75)
labeling(modes, game_counts)

plt.savefig("./img/stat_1.png")

# %%
# Statistics TWO: How many games does player X and O won, respectively?
outcomes = df['result'].value_counts().keys().tolist()
game_counts = df['result'].value_counts().tolist()

plt.figure(figsize=(6, 8), dpi=120)
plt.bar(outcomes[:2], game_counts[:2], width=0.75)
labeling(outcomes[:2], game_counts[:2])

plt.savefig("./img/stat_2.png")

# %%
# Statistics THREE: How many games ended in draw compared to the total games played?
draw_and_total_compare = [ df['result'].value_counts()[2], len(df)]
labels = ['Draw', 'Total Games']

plt.figure(figsize=(6, 8), dpi=120)
plt.bar(labels, draw_and_total_compare, width=0.75)
labeling(labels, draw_and_total_compare)

plt.savefig("./img/stat_3.png")
